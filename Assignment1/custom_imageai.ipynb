# %%
from imageai.Prediction.Custom import ModelTraining

model_trainer = ModelTraining()

# %%
model_trainer.setModelTypeAs

# %%
model_trainer.setDataDirectory("imageai/assignment_data/")

# %%
model_trainer.trainModel(num_objects=4, num_experiments=100, enhance_data=True, batch_size=16, show_network_summary=True)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_3 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv2d_107 (Conv2D)              (None, 112, 112, 64)  9472        input_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_107 (BatchNo (None, 112, 112, 64)  256         conv2d_107[0][0]
# ____________________________________________________________________________________________________
# activation_101 (Activation)      (None, 112, 112, 64)  0           batch_normalization_107[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
from imageai.Prediction.Custom import CustomImagePrediction

prediction = CustomImagePrediction()

# %%
prediction.setModelTypeAsResNet()

# %%
prediction.setModelPath('imageai/assignment_data/models/model_ex-026_acc-0.829545.h5')

# %%
prediction.setJsonPath("imageai/assignment_data/json/model_class.json")

# %%
prediction.loadModel(num_objects=4)

# %%
predictions, probabilities = prediction.predictImage("sample_test/easy_multi_2.jpg", result_count=4)
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# class4  :  80.73893785476685
# class1  :  18.053799867630005
# class2  :  0.8359695784747601
# class3  :  0.3712923265993595
